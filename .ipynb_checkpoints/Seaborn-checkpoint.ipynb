# %% [markdown]
# # Seaborn

# %%
# %matplotlib inline
import pandas as pd

x=pd.read_csv("http://media.sundog-soft.com/SelfDriving/FuelEfficiency.csv")
y=x['# Gears'].value_counts()
y.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
x
# Out:
#                 Mfr Name                 Carline  Eng Displ  Cylinders  \
# 0           aston martin              Vantage V8        4.0          8
# 1    Volkswagen Group of                  Chiron        8.0         16
# 2         General Motors                CORVETTE        6.2          8
# 3         General Motors                CORVETTE        6.2          8
# 4         General Motors                CORVETTE        6.2          8
# ..                   ...                     ...        ...        ...
# 713               Toyota             4RUNNER 4WD        4.0          6
# 714               Toyota  LAND CRUISER WAGON 4WD        5.7          8
# 715               Toyota             SEQUOIA 4WD        5.7          8
# 716                Volvo                XC90 AWD        2.0          4
# 717                Volvo                XC90 AWD        2.0          4
#
#     Transmission  CityMPG  HwyMPG  CombMPG  # Gears
# 0       Auto(S8)       18      25       21        8
# ...

# %%
import seaborn as sns
sns.set()

# %%
y.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
x.head(20)
# Out:
#                Mfr Name                    Carline  Eng Displ  Cylinders  \
# 0          aston martin                 Vantage V8        4.0          8
# 1   Volkswagen Group of                     Chiron        8.0         16
# 2        General Motors                   CORVETTE        6.2          8
# 3        General Motors                   CORVETTE        6.2          8
# 4        General Motors                   CORVETTE        6.2          8
# 5        General Motors                   CORVETTE        6.2          8
# 6        General Motors                   CORVETTE        6.2          8
# 7        General Motors                   CORVETTE        6.2          8
# 8               Ferrari                    488 gtb        3.9          8
# 9               Ferrari                    488 gtb        3.9          8
# 10              Ferrari                  488 Pista        3.9          8
# 11              Ferrari           488 Pista Spider        3.9          8
# ...

# %%
sns.displot(x["CombMPG"])

# %%
y=x[['Cylinders','Transmission','CombMPG','# Gears']]
y.head()
# Out:
#    Cylinders Transmission  CombMPG  # Gears
# 0          8     Auto(S8)       21        8
# 1         16  Auto(AM-S7)       11        7
# 2          8     Auto(S8)       15        8
# 3          8     Auto(S8)       18        8
# 4          8     Auto(S8)       17        8

# %%
sns.pairplot(y,hue='Cylinders',height=3)
# Out:
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.scatterplot(x='Cylinders',y='CombMPG',data=x)
# Out:
# <AxesSubplot:xlabel='Cylinders', ylabel='CombMPG'>

# %%
sns.jointplot(x='Cylinders',y='CombMPG',data=x)

# %%
sns.lmplot(x='Cylinders',y='CombMPG',data=y)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
x=pd.read_csv("http://media.sundog-soft.com/SelfDriving/FuelEfficiency.csv")
x.head()
# Out:
#               Mfr Name     Carline  Eng Displ  Cylinders Transmission  \
# 0         aston martin  Vantage V8        4.0          8     Auto(S8)
# 1  Volkswagen Group of      Chiron        8.0         16  Auto(AM-S7)
# 2       General Motors    CORVETTE        6.2          8     Auto(S8)
# 3       General Motors    CORVETTE        6.2          8     Auto(S8)
# 4       General Motors    CORVETTE        6.2          8     Auto(S8)
#
#    CityMPG  HwyMPG  CombMPG  # Gears
# 0       18      25       21        8
# 1        9      14       11        7
# 2       12      20       15        8
# 3       15      25       18        8
# 4       14      23       17        8

# %%
sns.pairplot(x,hue='Mfr Name',height=2.5)
# Out:
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# # Boxplot

# %%
sns.set(rc={'figure.figsize':(20,7)})
a=sns.boxplot(x='Mfr Name',y='CombMPG',data=x)
a.set_xticklabels(a.get_xticklabels(),rotation=60)
# Out:
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]

# %% [markdown]
# # Swarmplot

# %%
a=sns.swarmplot(x='Mfr Name',y='CombMPG',data=x)
a.set_xticklabels(a.get_xticklabels(),rotation=50)
# Out:
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 19.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 19.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/hrithikrana/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 19.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
# ...

# %% [markdown]
# # Countplot

# %%
a=sns.countplot(x='Mfr Name',data=x)
a.set_xticklabels(a.get_xticklabels(),rotation=60)
# Out:
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]

# %% [markdown]
# # Heatmap

# %%
y=x.pivot_table(index='Cylinders',columns='Eng Displ',values='CityMPG',aggfunc='mean')
sns.heatmap(y)
# Out:
# <AxesSubplot:xlabel='Eng Displ', ylabel='Cylinders'>

# %%
sns.scatterplot(x='# Gears',y='CombMPG',data=x)
# Out:
# <AxesSubplot:xlabel='# Gears', ylabel='CombMPG'>

# %%
sns.lmplot(x='# Gears',y='CombMPG',data=x)

# %%
sns.jointplot(x='# Gears',y='CombMPG',data=x)

# %%
sns.boxplot(x='# Gears',y='CombMPG',data=x)
# Out:
# <AxesSubplot:xlabel='# Gears', ylabel='CombMPG'>

# %%
sns.swarmplot(x='# Gears',y='CombMPG',data=x)
# Out:
# <AxesSubplot:xlabel='# Gears', ylabel='CombMPG'>
