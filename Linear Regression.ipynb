# %% [markdown]
# # Linear Regression

# %%
# %matplotlib inline
import numpy as np
from pylab import *
page_speed=np.random.normal(3.0,1.0,1000)
purchase_amount=100+(page_speed+np.random.normal(0,0.1,1000)) * 3
scatter(page_speed,purchase_amount)

# %%
from scipy import stats
slope,intercept,r_value,p_value,std_err=stats.linregress(page_speed,purchase_amount)

# %%
r_value ** 2
# Out:
# 0.9900607362194885

# %%
import matplotlib.pyplot as plt
def predict(x):
    return slope*x + intercept
line=predict(page_speed)
plt.scatter(page_speed,purchase_amount)
plt.plot(page_speed,line,c='r')
plt.show()

# %%
np.random.seed(2)
pageSpeed=np.random.normal(3.0,1.0,1000)
purchaseAmount=np.random.normal(50.0,30.0,1000)/pageSpeed
scatter(pageSpeed,purchaseAmount)

# %%
trainX=pageSpeed[:800]
testX=pageSpeed[800:]

trainY=purchaseAmount[:800]
testY=purchaseAmount[800:]

# %%
scatter(trainX,trainY)

# %%
scatter(testX,testY)

# %%
x=np.random.normal(10,4,500)
y=np.random.normal(x+np.random.normal(20,8,500))
scatter(x,y)
